# %% [markdown]
# <a href="https://colab.research.google.com/github/malraharsh/Pruning-Experiments/blob/master/Pruning_Experiments_on_DogsvsCats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q tensorflow-model-optimization

import tempfile
import os

import tensorflow as tf
import numpy as np

from sklearn.model_selection import train_test_split
import pandas as pd


from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

from tensorflow import keras
import datetime

# %load_ext tensorboard

import tensorflow_model_optimization as tfmot
from tensorflow_model_optimization.sparsity.keras import prune_low_magnitude, ConstantSparsity

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import numpy as np
import matplotlib.pyplot as plt



from IPython.display import display

SHOW = False
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
def makedir(path):
    os.makedirs(path, exist_ok=True)

# %%
log_train = 'logs/train/'
log_prune = 'logs/prune/'

makedir(log_train)
makedir(log_prune)

# %%
#https://www.tensorflow.org/tutorials/images/classification

_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'

path_to_zip = tf.keras.utils.get_file('cats_and_dogs.zip', origin=_URL, extract=True)

PATH = os.path.join(os.path.dirname(path_to_zip), 'cats_and_dogs_filtered')

# %%
# train_dir = os.path.join(PATH, 'train')
# validation_dir = os.path.join(PATH, 'validation')
train_dir = os.path.join(PATH, 'validation')
validation_dir = os.path.join(PATH, 'train')

train_cats_dir = os.path.join(train_dir, 'cats')  # directory with our training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')  # directory with our training dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')  # directory with our validation cat pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')  # directory with our validation dog pictures

num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
batch_size = 128
epochs = 15
IMG_HEIGHT = 150
IMG_WIDTH = 150

train_image_generator = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5)

validation_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our validation data


train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                           class_mode='binary')

val_data_gen = validation_image_generator.flow_from_directory(batch_size=batch_size,
                                                              directory=validation_dir,
                                                              target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                              class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
def get_train_model():

    model = Sequential([
    Conv2D(16, 3, padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH ,3)),
    MaxPooling2D(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1)])

    model.compile(optimizer='adam',
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=['accuracy'])
    
    return model

# %%
def train(model=None):#train_images, train_labels, test_images, test_labels):

    if model is None:
        model = get_train_model()

    log_dir = log_train + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_train, histogram_freq=1)

    history = model.fit(
    train_data_gen,
    steps_per_epoch=total_train // batch_size,
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=total_val // batch_size,
    callbacks=[tensorboard_callback])
    
    return model, history.history

# %%
def prune(model=None):

    if model is None:
        model = get_train_model()

    # Compute end step to finish pruning after 2 epochs.
    batch_size = 128

    # Define model for pruning.
    pruning_params = {
        'pruning_schedule': ConstantSparsity(pct_prune, 0), #target, begin step
        'block_size': (1, 1),
        'block_pooling_type': 'AVG'}

    end_step = np.ceil(total_val / batch_size).astype(np.int32) * epochs

    pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.0,
                                                               final_sparsity=pct_prune,
                                                               begin_step=0,
                                                               end_step=end_step)}


    model_for_pruning = prune_low_magnitude(model, **pruning_params)

    # `prune_low_magnitude` requires a recompile.
    model_for_pruning.compile(optimizer='adam',
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    callbacks = [
      tfmot.sparsity.keras.UpdatePruningStep(),
      tfmot.sparsity.keras.PruningSummaries(log_dir=log_prune),
    ]

    history = model_for_pruning.fit(
    train_data_gen,
    steps_per_epoch=total_train // batch_size,
    epochs=EPOCHS_PRUNE,
    validation_data=val_data_gen,
    validation_steps=total_val // batch_size,
    callbacks=callbacks,
    verbose=VERBOSE)

    return model_for_pruning, history.history

# %%
EPOCHS = 1
EPOCHS_PRUNE = 2
VERBOSE = 1
SHOW = 0
pct_prune = 0.05

# %%
EPOCHS = 250
model, dt = train(model)
# Out:
# Epoch 1/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.5085 - accuracy: 0.7362 - val_loss: 0.5464 - val_accuracy: 0.7339
# Epoch 2/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.5255 - accuracy: 0.7236 - val_loss: 0.5247 - val_accuracy: 0.7401
# Epoch 3/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.5091 - accuracy: 0.7305 - val_loss: 0.6071 - val_accuracy: 0.7021
# Epoch 4/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.5483 - accuracy: 0.7041 - val_loss: 0.5546 - val_accuracy: 0.7302
# Epoch 5/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.5146 - accuracy: 0.7210 - val_loss: 0.5206 - val_accuracy: 0.7385
# Epoch 6/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.5182 - accuracy: 0.7190 - val_loss: 0.5449 - val_accuracy: 0.7339
# Epoch 7/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.5068 - accuracy: 0.7236 - val_loss: 0.5268 - val_accuracy: 0.7396
# Epoch 8/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.5098 - accuracy: 0.7225 - val_loss: 0.5407 - val_accuracy: 0.7109
# Epoch 9/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.5283 - accuracy: 0.7076 - val_loss: 0.5176 - val_accuracy: 0.7266
# Epoch 10/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.5349 - accuracy: 0.6858 - val_loss: 0.5596 - val_accuracy: 0.7406
# Epoch 11/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.5061 - accuracy: 0.7259 - val_loss: 0.5988 - val_accuracy: 0.7385
# Epoch 12/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.5062 - accuracy: 0.7420 - val_loss: 0.5017 - val_accuracy: 0.7401
# Epoch 13/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.4836 - accuracy: 0.7523 - val_loss: 0.5410 - val_accuracy: 0.7453
# Epoch 14/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.4762 - accuracy: 0.7580 - val_loss: 0.5126 - val_accuracy: 0.7417
# Epoch 15/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.4889 - accuracy: 0.7500 - val_loss: 0.5529 - val_accuracy: 0.6995
# Epoch 16/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.5145 - accuracy: 0.7259 - val_loss: 0.5074 - val_accuracy: 0.7625
# Epoch 17/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.4823 - accuracy: 0.7431 - val_loss: 0.5231 - val_accuracy: 0.7474
# Epoch 18/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.4952 - accuracy: 0.7431 - val_loss: 0.5222 - val_accuracy: 0.7292
# Epoch 19/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.4721 - accuracy: 0.7500 - val_loss: 0.5670 - val_accuracy: 0.7594
# Epoch 20/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.4626 - accuracy: 0.7557 - val_loss: 0.5335 - val_accuracy: 0.7672
# Epoch 21/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.4656 - accuracy: 0.7569 - val_loss: 0.5179 - val_accuracy: 0.7682
# Epoch 22/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.4762 - accuracy: 0.7683 - val_loss: 0.5337 - val_accuracy: 0.7604
# Epoch 23/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.4719 - accuracy: 0.7615 - val_loss: 0.5548 - val_accuracy: 0.7646
# Epoch 24/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.
250
# 7/7 [==============================] - 14s 2s/step - loss: 0.2677 - accuracy: 0.8830 - val_loss: 0.6389 - val_accuracy: 0.7854
# Epoch 232/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.2453 - accuracy: 0.8796 - val_loss: 0.7310 - val_accuracy: 0.7880
# Epoch 233/250
# 7/7 [==============================] - 14s 2s/step - loss: 0.2501 - accuracy: 0.8991 - val_loss: 0.7006 - val_accuracy: 0.7906
# Epoch 234/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2538 - accuracy: 0.8899 - val_loss: 0.6624 - val_accuracy: 0.7906
# Epoch 235/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2547 - accuracy: 0.8853 - val_loss: 0.6291 - val_accuracy: 0.7854
# Epoch 236/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2268 - accuracy: 0.8899 - val_loss: 0.7291 - val_accuracy: 0.7802
# Epoch 237/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2484 - accuracy: 0.9002 - val_loss: 0.6222 - val_accuracy: 0.7734
# Epoch 238/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2423 - accuracy: 0.8899 - val_loss: 0.6468 - val_accuracy: 0.7750
# Epoch 239/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2149 - accuracy: 0.9083 - val_loss: 0.5864 - val_accuracy: 0.7974
# Epoch 240/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2330 - accuracy: 0.8945 - val_loss: 0.6095 - val_accuracy: 0.7807
# Epoch 241/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2385 - accuracy: 0.8750 - val_loss: 0.6330 - val_accuracy: 0.7771
# Epoch 242/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2263 - accuracy: 0.8940 - val_loss: 0.6561 - val_accuracy: 0.7693
# Epoch 243/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2436 - accuracy: 0.8888 - val_loss: 0.6796 - val_accuracy: 0.7651
# Epoch 244/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2450 - accuracy: 0.8940 - val_loss: 0.5816 - val_accuracy: 0.7911
# Epoch 245/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2518 - accuracy: 0.8956 - val_loss: 0.6051 - val_accuracy: 0.7854
# Epoch 246/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2378 - accuracy: 0.8895 - val_loss: 0.6647 - val_accuracy: 0.7901
# Epoch 247/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2479 - accuracy: 0.8899 - val_loss: 0.6334 - val_accuracy: 0.7891
# Epoch 248/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2366 - accuracy: 0.8956 - val_loss: 0.6414 - val_accuracy: 0.7911
# Epoch 249/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2176 - accuracy: 0.9060 - val_loss: 0.6602 - val_accuracy: 0.7943
# Epoch 250/250
# 7/7 [==============================] - 13s 2s/step - loss: 0.2203 - accuracy: 0.9048 - val_loss: 0.6302 - val_accuracy: 0.7875

# %%
path_cp = f"training_cp-1000train, 2000val, 300epochs---{EPOCHS:04d}.h5"
model.save(path_cp)

loaded = tf.keras.models.load_model(path_cp)

# %%
EPOCHS_PRUNE = 3
pct_prune = 0.05
mp, dp = prune(model)
# Out:
# Epoch 1/3
# 7/7 [==============================] - 13s 2s/step - loss: 0.6004 - accuracy: 0.6663 - val_loss: 0.5468 - val_accuracy: 0.7141
# Epoch 2/3
# 7/7 [==============================] - 13s 2s/step - loss: 0.5791 - accuracy: 0.6709 - val_loss: 0.5677 - val_accuracy: 0.6990
# Epoch 3/3
# 7/7 [==============================] - 13s 2s/step - loss: 0.5524 - accuracy: 0.6800 - val_loss: 0.5470 - val_accuracy: 0.7385

# %%
e = '/content/drive/My Drive/Colab Notebooks/Pruning Experiments'
makedir(e)

# %%
# !cp '/content/training_cp-1000train, 2000val, 300epochs---0250.h5' '/content/drive/My Drive/Colab Notebooks/Pruning Experiments'

# %%
pct_prune = 0.1
mp, dp = prune(model)
# Out:
# Epoch 1/3
# 7/7 [==============================] - 13s 2s/step - loss: 0.5985 - accuracy: 0.6732 - val_loss: 0.5752 - val_accuracy: 0.6359
# Epoch 2/3
# 7/7 [==============================] - 13s 2s/step - loss: 0.5573 - accuracy: 0.6869 - val_loss: 0.5605 - val_accuracy: 0.7276
# Epoch 3/3
# 7/7 [==============================] - 13s 2s/step - loss: 0.5431 - accuracy: 0.7122 - val_loss: 0.5512 - val_accuracy: 0.7172

# %%
pct_prune = 0.2
mp, dp = prune(model)
# Out:
# Epoch 1/3
# 7/7 [==============================] - 13s 2s/step - loss: 0.6197 - accuracy: 0.6514 - val_loss: 0.5928 - val_accuracy: 0.6854
# Epoch 2/3
# 7/7 [==============================] - 13s 2s/step - loss: 0.5815 - accuracy: 0.6640 - val_loss: 0.5756 - val_accuracy: 0.6938
# Epoch 3/3
# 7/7 [==============================] - 13s 2s/step - loss: 0.5614 - accuracy: 0.6927 - val_loss: 0.5634 - val_accuracy: 0.7010

# %%
EPOCHS_PRUNE = 10
pct_prune = 0.1
mp, dp = prune(model)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.5787 - accuracy: 0.6560 - val_loss: 0.5719 - val_accuracy: 0.6964
# Epoch 2/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.5740 - accuracy: 0.6835 - val_loss: 0.5912 - val_accuracy: 0.7323
# Epoch 3/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.5571 - accuracy: 0.6915 - val_loss: 0.5484 - val_accuracy: 0.7339
# Epoch 4/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.5515 - accuracy: 0.6972 - val_loss: 0.5282 - val_accuracy: 0.7203
# Epoch 5/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.5207 - accuracy: 0.7110 - val_loss: 0.5359 - val_accuracy: 0.7281
# Epoch 6/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.5226 - accuracy: 0.7110 - val_loss: 0.5761 - val_accuracy: 0.6646
# Epoch 7/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.5661 - accuracy: 0.6950 - val_loss: 0.5349 - val_accuracy: 0.7448
# Epoch 8/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.5179 - accuracy: 0.7007 - val_loss: 0.5209 - val_accuracy: 0.7448
# Epoch 9/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.5002 - accuracy: 0.7339 - val_loss: 0.5332 - val_accuracy: 0.7427
# Epoch 10/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.5041 - accuracy: 0.7277 - val_loss: 0.5373 - val_accuracy: 0.7396

# %%
# %tensorboard --logdir /content/logs/train

# %%
# %tensorboard --logdir /content/logs/prune
